# %% [markdown]
# # NVEL published DLL with CTypes

# %%
from ctypes import byref, cdll, c_int, c_float,c_char,c_char_p,Structure

nvel = cdll.LoadLibrary(r'C:\progs\FMSC Software\VolLibDll20230221\vollib-64bits\vollib.dll')

# %%
# Get the default equation

variant = c_char_p(b'PN')
region = c_int(6)
forest = c_char_p(b'12')
district = c_char_p(b'01')
species = c_int(202)
product = c_char_p(b'01')
voleq = c_char_p(b' '*10)
error_flag = c_int(0)

nvel.VOLEQDEF(
  variant,
  byref(region),
  forest,
  district,
  byref(species),
  product,
  voleq,
  byref(error_flag),
  2,2,2,2,10
)

print(voleq.value)
# Out:
# b'F00FW2W202'

# %%
dbh = 18.0
height = 120.0
fc = 80

voleq = c_char_p(b'F02FW2W202')

variant = c_char_p(b'PN')
# district = c_char_p(b'01')
# species = c_int(202)
product = c_char_p(b'01')

region = c_int(6)
forest = c_char_p(b'01')
voleq = c_char_p(b' '*10)
min_top_prim = c_float(5.0)
min_top_sec = c_float(2.0)
stump_ht = c_float(1.0)
dbh_ob = c_float(dbh)
drc_ob = c_float(0.0)
ht_type = c_char_p(b'F')
total_ht = c_float(height)
ht_log = c_int()
ht_prim = c_float(0)
ht_sec = c_float(0)
upper_ht1 = c_float(0)
upper_ht2 = c_float(0)
upper_diam1 = c_float(0)
upper_diam2 = c_float(0)
ht_ref = c_int(0)
avg_z1 = c_float(0)
avg_z2 = c_float(0)
form_class = c_int(fc)
bark_thick = c_float(0)
bark_ratio = c_float(0)
# i3 = c_int(3)
# i7 = c_int(7)
# i15 = c_int(15)
# i20 = c_int(20)
# i21 = c_int(21)

volume_wk = (c_float*15)()
log_vol_wk = ((c_float*7)*20)()
log_diam_wk = ((c_float*21)*3)()
log_len_wk = (c_float*20)()
bole_ht_wk = (c_float*21)()

num_logs = c_int(0)
num_logs_prim = c_float(0)
num_logs_sec = c_float(0)
cubic_total_flag = c_int(1)
bdft_prim_flag = c_int(1)
cubic_prim_flag = c_int(1)
cord_prim_flag = c_int(1)
sec_vol_flag = c_int(1)
con_spp = c_char_p(b' '*6)
prod_code = c_char_p(b'01')
ht_1st_limb = c_int(0)
live = c_char_p(b'L')
basal_area = c_int(0)
site_index = c_int(0)
cruise_type = c_char_p(b'C')
error_flag = c_int(0)
idist = c_int(0)

brkht = c_float(0)
brkhtd = c_float(0)
fiasp = c_int(0)
drybio = c_float(0)
grnbio = c_float(0)
cr_ratio = c_float(0)
cull = c_float(0)
decay_code = c_int(0)

class MerchRule(Structure):
    _fields_ = [
        ('evod', c_int),
        ('opt', c_int),
        ('maxlen', c_float),
        ('minlen', c_float),
        ('minlent', c_float),
        ('merchl', c_float),
        ('mtopp', c_float),
        ('mtops', c_float),
        ('stump', c_float),
        ('trim', c_float),
        ('btr', c_float),
        ('dbtbh', c_float),
        ('minbfd', c_float),
        #NOTE: **Must be single char, not pointer. Unsure how to pass a len arg in a struct
        ('cor', c_char)
        ]

mrule = MerchRule()
mrule.evod = 1
mrule.opt = 23
mrule.maxlen = 40.0
mrule.minlen = 12.0
mrule.minlent = 12.0
mrule.merchl = 12.0
mrule.mtopp = 5.0
mrule.mtops = 2.0
mrule.stump = 1.0
mrule.trim = 1.0
mrule.btr = 0.0
mrule.dbtbh = 0.0
mrule.minbfd = 8.0
mrule.cor = b'N'

r = nvel.VOLUMELIBRARY2(
    byref(region)
    , forest
    # , 2
    , voleq
    # , 10
    , byref(min_top_prim)
    , byref(min_top_sec)
    , byref(stump_ht)
    , byref(dbh_ob)
    , byref(drc_ob)
    , ht_type
    # , 1
    , byref(total_ht)
    , byref(ht_log)
    , byref(ht_prim)
    , byref(ht_sec)
    , byref(upper_ht1)
    , byref(upper_ht2)
    , byref(upper_diam1)
    , byref(upper_diam2)
    , byref(ht_ref)
    , byref(avg_z1)
    , byref(avg_z2)
    , byref(form_class)
    , byref(bark_thick)
    , byref(bark_ratio)
    , byref(volume_wk)
    , byref(log_vol_wk)
    , byref(log_diam_wk)
    , byref(log_len_wk)
    , byref(bole_ht_wk)
    , byref(num_logs)
    , byref(num_logs_prim)
    , byref(num_logs_sec)
    , byref(cubic_total_flag)
    , byref(bdft_prim_flag)
    , byref(cubic_prim_flag)
    , byref(cord_prim_flag)
    , byref(sec_vol_flag)
    , con_spp
    # , 6
    , prod_code
    # , 2
    , byref(ht_1st_limb)
    , live
    # , 1
    , byref(basal_area)
    , byref(site_index)
    , cruise_type
    # , 1
    , byref(error_flag)
    , byref(idist)
    , byref(brkht)
    , byref(brkhtd)
    , byref(fiasp)
    , byref(drybio)
    , byref(grnbio)
    , byref(cr_ratio)
    , byref(cull)
    , byref(decay_code)

        
    ,2,10,1, 6,2,1,1
    )

print('Error:', error_flag.value)
print('Num Logs:', num_logs.value)
print('Tot CuFt:', volume_wk[0])
print('Net BdFt:', volume_wk[1])
print('Net CuFt:', volume_wk[3])
print('Top CuFt:', volume_wk[6])
print('Stump CuFt:', volume_wk[13])
print('Tip CuFt:', volume_wk[14])
print(volume_wk[14]+volume_wk[13]+volume_wk[6]+volume_wk[3])

print('')
for i,l in enumerate(log_len_wk):
    print(log_len_wk[i])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 109
#     106 mrule.minbfd = 8.0
#     107 mrule.cor = b'N'
# --> 109 r = nvel.VOLUMELIBRARY2(
#     110     byref(region)
#     111     , forest
#     112     # , 2
#     113     , voleq
#     114     # , 10
#     115     , byref(min_top_prim)
#     116     , byref(min_top_sec)
#     117     , byref(stump_ht)
#     118     , byref(dbh_ob)
#     119     , byref(drc_ob)
#     120     , ht_type
#     121     # , 1
#     122     , byref(total_ht)
#     123     , byref(ht_log)
#     124     , byref(ht_prim)
#     125     , byref(ht_sec)
#     126     , byref(upper_ht1)
#     127     , byref(upper_ht2)
#     128     , byref(upper_diam1)
#     129     , byref(upper_diam2)
#     130     , byref(ht_ref)
#     131     , byref(avg_z1)
#     132     , byref(avg_z2)
#     133     , byref(form_class)
#     134     , byref(bark_thick)
#     135     , byref(bark_ratio)
#     136     , byref(volume_wk)
#     137     , byref(log_vol_wk)
#     138     , byref(log_diam_wk)
#     139     , byref(log_len_wk)
#     140     , byref(bole_ht_wk)
#     141     , byref(num_logs)
#     142     , byref(num_logs_prim)
#     143     , byref(num_logs_sec)
#     144     , byref(cubic_total_flag)
#     145     , byref(bdft_prim_flag)
#     146     , byref(cubic_prim_flag)
#     147     , byref(cord_prim_flag)
#     148     , byref(sec_vol_flag)
#     149     , con_spp
#     150     # , 6
#     151     , prod_code
#     152     # , 2
#     153     , byref(ht_1st_limb)
#     154     , live
#     155     # , 1
#     156     , byref(basal_area)
#     157     , byref(site_index)
#     158     , cruise_type
#     159     # , 1
#     160     , byref(error_flag)
#     161     , byref(idist)
#     162     , byref(brkht)
#     163     , byref(brkhtd)
#     164     , byref(fiasp)
#     165     , byref(drybio)
#     166     , byref(grnbio)
#     167     , byref(cr_ratio)
#     168     , byref(cull)
#     169     , byref(decay_code)
#     170
#     171
#     172     ,2,10,1, 6,2,1,1
#     173     )
#     175 print('Error:', error_flag.value)
#     176 print('Num Logs:', num_logs.value)
#
# OSError: exception: access violation writing 0x0000000000000001
